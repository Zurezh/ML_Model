# %% [markdown]
# # Step 1: Installation and Setup

# %%
# Installing TensorFlow
! pip install -q tensorflow-gpu
# Out:
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       Traceback (most recent call last):
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/requirements.py", line 35, in __init__
#           parsed = _parse_requirement(requirement_string)
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/_parser.py", line 64, in parse_requirement
#           return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/_parser.py", line 82, in _parse_requirement
#           url, specifier, marker = _parse_requirement_details(tokenizer)
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/_parser.py", line 126, in _parse_requirement_details
#           marker = _parse_requirement_marker(
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/_parser.py", line 147, in _parse_requirement_marker
#           tokenizer.raise_syntax_error(
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/_tokenizer.py", line 165, in raise_syntax_error
#           raise ParserSyntaxError(
#       setuptools.extern.packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/v2/l1w3nbds29b7l6v64kqn5cj40000gn/T/pip-install-b13u39fb/tensorflow-gpu_491a787e2db74c3fa25cc8395d52fa1d/setup.py", line 40, in <module>
#           setuptools.setup()
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/__init__.py", line 106, in setup
#           _install_setup_requires(attrs)
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/__init__.py", line 77, in _install_setup_requires
#           dist.parse_config_files(ignore_option_errors=True)
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/dist.py", line 901, in parse_config_files
#           self._finalize_requires()
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/dist.py", line 596, in _finalize_requires
#           self._move_install_requirements_markers()
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/dist.py", line 636, in _move_install_requirements_markers
#           inst_reqs = list(_reqs.parse(spec_inst_reqs))
#         File "/Users/lallu/Library/Python/3.9/lib/python/site-packages/setuptools/_vendor/packaging/requirements.py", line 37, in __init__
#           raise InvalidRequirement(str(e)) from e
#       setuptools.extern.packaging.requirements.InvalidRequirement: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.13.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2: Data Preprocessing

# %%
# importing the dataset
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/lallu/Documents/Upskilling/GitHub/MLProjects/MachineLearningModels/Projects ML and Deep Learning/Project 21_ Google Stock Price Prediction with RNN and LSTM.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/lallu/Documents/Upskilling/GitHub/MLProjects/MachineLearningModels/Projects%20ML%20and%20Deep%20Learning/Project%2021_%20Google%20Stock%20Price%20Prediction%20with%20RNN%20and%20LSTM.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # importing the dataset
# ----> <a href='vscode-notebook-cell:/Users/lallu/Documents/Upskilling/GitHub/MLProjects/MachineLearningModels/Projects%20ML%20and%20Deep%20Learning/Project%2021_%20Google%20Stock%20Price%20Prediction%20with%20RNN%20and%20LSTM.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> from google.colab import files
#       <a href='vscode-notebook-cell:/Users/lallu/Documents/Upskilling/GitHub/MLProjects/MachineLearningModels/Projects%20ML%20and%20Deep%20Learning/Project%2021_%20Google%20Stock%20Price%20Prediction%20with%20RNN%20and%20LSTM.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
training_data = pd.read_csv('/content/training_set.csv')

# %%
training_data.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2014-11-03  553.979065  556.372498  ...  553.699829  553.699829  1382200
# 1  2014-11-04  551.485901  553.979065  ...  552.592834  552.592834  1244200
# 2  2014-11-05  555.275513  555.275513  ...  544.425293  544.425293  2032200
# 3  2014-11-06  544.006409  545.387634  ...  540.555908  540.555908  1333200
# 4  2014-11-07  544.714478  544.714478  ...  539.528748  539.528748  1633700
#
# [5 rows x 7 columns]

# %%
training_data.tail()
# Out:
#             Date         Open         High  ...        Close    Adj Close   Volume
# 1252  2019-10-24  1260.900024  1264.000000  ...  1260.989990  1260.989990  1028100
# 1253  2019-10-25  1251.030029  1269.599976  ...  1265.130005  1265.130005  1213100
# 1254  2019-10-28  1275.449951  1299.310059  ...  1290.000000  1290.000000  2613200
# 1255  2019-10-29  1276.229980  1281.589966  ...  1262.619995  1262.619995  1886400
# 1256  2019-10-30  1252.969971  1269.359985  ...  1261.290039  1261.290039  1408900
#
# [5 rows x 7 columns]

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 7 columns):
# Date         1257 non-null object
# Open         1257 non-null float64
# High         1257 non-null float64
# Low          1257 non-null float64
# Close        1257 non-null float64
# Adj Close    1257 non-null float64
# Volume       1257 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
training_set = training_data.iloc[:, 1:2].values

# %%
training_set.shape, training_data.shape
# Out:
# ((1257, 1), (1257, 7))

# %%
# feature scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[0.07750766],
#        [0.07432328],
#        [0.07916355],
#        ...,
#        [0.99900371],
#        [1.        ],
#        [0.97029124]])

# %%
# Creating a data structure with 60 timesteps and 1 output
x_train = []
y_train = []

for i in range(60, 1257):
  x_train.append(training_set_scaled[i-60:i, 0])
  y_train.append(training_set_scaled[i, 0])

# converting x_train and y_train into numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train
# Out:
# array([[0.07750766, 0.07432328, 0.07916355, ..., 0.04498879, 0.03583056,
#         0.0208258 ],
#        [0.07432328, 0.07916355, 0.06477013, ..., 0.03583056, 0.0208258 ,
#         0.02701621],
#        [0.07916355, 0.06477013, 0.0656745 , ..., 0.0208258 , 0.02701621,
#         0.0472306 ],
#        ...,
#        [0.90358069, 0.86436929, 0.85577344, ..., 0.95673967, 0.98041987,
#         0.96781345],
#        [0.86436929, 0.85577344, 0.8464367 , ..., 0.98041987, 0.96781345,
#         0.99900371],
#        [0.85577344, 0.8464367 , 0.88070516, ..., 0.96781345, 0.99900371,
#         1.        ]])

# %%
y_train
# Out:
# array([0.02701621, 0.0472306 , 0.04247951, ..., 0.99900371, 1.        ,
#        0.97029124])

# %%
x_train.shape
# Out:
# (1197, 60)

# %%
# reshaping dataset
x_train = x_train.reshape(1197, 60, 1)

# %%
x_train.shape
# Out:
# (1197, 60, 1)

# %% [markdown]
# # Step 3: Building LSTM

# %%
# define an object (inilitizing RNN)
model = tf.keras.models.Sequential()

# %%
# first LSTM layer
model.add(tf.keras.layers.LSTM(units=60, activation='relu', return_sequences=True, input_shape=(60,1)))
# dropout layer
model.add(tf.keras.layers.Dropout(0.2))

# second LSTM layer
model.add(tf.keras.layers.LSTM(units=60, activation='relu', return_sequences=True))
# dropout layer
model.add(tf.keras.layers.Dropout(0.2))

# third LSTM layer
model.add(tf.keras.layers.LSTM(units=80, activation='relu', return_sequences=True))
# dropout layer
model.add(tf.keras.layers.Dropout(0.2))

# fourth LSTM layer
model.add(tf.keras.layers.LSTM(units=120, activation='relu'))
# dropout layer
model.add(tf.keras.layers.Dropout(0.2))

# %%
# output layer
model.add(tf.keras.layers.Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 60)            14880
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 60)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 60)            29040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 60)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 80)            45120
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 80)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120)               96480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 121
# =================================================================
# Total params: 185,641
# Trainable params: 185,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# # Step 4: Training the model

# %%
model.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# Train on 1197 samples
# Epoch 1/100
# 1197/1197 [==============================] - 12s 10ms/sample - loss: 0.0772
# Epoch 2/100
# 1197/1197 [==============================] - 7s 6ms/sample - loss: 0.0075
# Epoch 3/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0056
# Epoch 4/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0058
# Epoch 5/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0058
# Epoch 6/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0055
# Epoch 7/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0051
# Epoch 8/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0059
# Epoch 9/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0046
# Epoch 10/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0048
# Epoch 11/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0047
# Epoch 12/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0050
# Epoch 13/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0044
# Epoch 14/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0042
# Epoch 15/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0045
# Epoch 16/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0045
# Epoch 17/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0043
# Epoch 18/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0041
# Epoch 19/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0039
# Epoch 20/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0037
# Epoch 21/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0036
# Epoch 22/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0039
# Epoch 23/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0037
# Epoch 24/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0040
# Epoch 25/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0040
# Epoch 26/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0040
# Epoch 27/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0035
# Epoch 28/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0038
# Epoch 29/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0037
# Epoch 30/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0038
# Epoch 31/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0032
# Epoch 32/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0035
# Epoch 33/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0040
# Epoch 34/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0041
# Epoch 35/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0037
# Epoch 36/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0031
# Epoch 37/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0032
# Epoch 38/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0034
# Epoch 39/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0033
# Epoch 40/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0030
# Epoch 41/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0033
# Epoch 42/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0027
# Epoch 43/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0031
# Epoch 44/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0030
# Epoch 45/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0030
# Epoch 46/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0029
# Epoch 47/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0030
# Epoch 48/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0028
# Epoch 49/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0028
# Epoch 50/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0027
# Epoch 51/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0031
# Epoch 52/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0026
# Epoch 53/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0030
# Epoch 54/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0031
# Epoch 55/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0027
# Epoch 56/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0029
# Epoch 57/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0034
# Epoch 58/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0026
# Epoch 59/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0025
# Epoch 60/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0029
# Epoch 61/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0026
# Epoch 62/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0026
# Epoch 63/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0026
# Epoch 64/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0026
# Epoch 65/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0025
# Epoch 66/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0025
# Epoch 67/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0027
# Epoch 68/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0024
# Epoch 69/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0024
# Epoch 70/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0022
# Epoch 71/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0027
# Epoch 72/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0023
# Epoch 73/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0028
# Epoch 74/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0023
# Epoch 75/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0023
# Epoch 76/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0025
# Epoch 77/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0024
# Epoch 78/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0024
# Epoch 79/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0026
# Epoch 80/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 81/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 82/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0021
# Epoch 83/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0021
# Epoch 84/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 85/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0022
# Epoch 86/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 87/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0021
# Epoch 88/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 89/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 90/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 91/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 92/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0024
# Epoch 93/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 94/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 95/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0022
# Epoch 96/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0020
# Epoch 97/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0020
# Epoch 98/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0021
# Epoch 99/100
# 1197/1197 [==============================] - 8s 7ms/sample - loss: 0.0021
# Epoch 100/100
# 1197/1197 [==============================] - 8s 6ms/sample - loss: 0.0019

# %% [markdown]
# # Step 5: Making Predictions

# %%
# getting the real stock prices of month Nov 2019
test_data = pd.read_csv('/content/test_set.csv')

# %%
test_data.shape
# Out:
# (20, 7)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
# Date         20 non-null object
# Open         20 non-null float64
# High         20 non-null float64
# Low          20 non-null float64
# Close        20 non-null float64
# Adj Close    20 non-null float64
# Volume       20 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
real_stock_price = test_data.iloc[:, 1:2].values

# %%
real_stock_price.shape
# Out:
# (20, 1)

# %%
# Getting predicted stock prices of month Nov 2019

# concatination
dataset_total = pd.concat((training_data['Open'], test_data['Open']), axis = 0)

# stock prices of previous 60 days for each day of Nov 2019
inputs = dataset_total[len(dataset_total) - len(test_data) - 60:].values

# reshape (convert into numpy array)
inputs = inputs.reshape(-1,1)

# feature scaling
inputs = sc.transform(inputs)

# creating a test set

x_test = []
for i in range(60, 80):
  x_test.append(inputs[i-60:i, 0])

# convert in numpy array
x_test = np.array(x_test)

# convert in 3D (required to process)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# getting predicted stock prices
predicted_stock_price = model.predict(x_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
print(predicted_stock_price[5]), print(real_stock_price[5])
# Out:
# [1230.0573]
# [1305.280029]
# (None, None)

# %% [markdown]
# # Step 6: Visualization

# %%
# Visualising the results
plt.plot(real_stock_price, color='red', label='Real Google Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
